# %%
import requests
from pprint import pprint
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as st
vaccination_path = "Vaccination Data/vaccination.csv"
vaccine_df = pd.read_csv(vaccination_path)
vaccine_df = vaccine_df.drop("Unnamed: 0", axis=1)
vaccine_df
# Out:
#    Province        Date  Vaccine dose:1   Booster vaccine: 2  \
# 0        AB  2023-04-03        3619485.0           3446403.0
# 1        BC  2023-04-03        4613061.0           4425788.0
# 2        MB  2023-04-03        1158894.0           1111163.0
# 3        NB  2023-04-03         705982.0            666950.0
# 4        NL  2023-04-03         505314.0            484281.0
# 5        NS  2023-04-03         914507.0            869721.0
# 6        NT  2023-04-03          34499.0             33044.0
# 7        NU  2023-04-03          34430.0             31716.0
# 8        ON  2023-04-03       12689223.0          12228410.0
# 9        PE  2023-04-03         153473.0            146679.0
# 10       QC  2023-04-03        7379821.0           7160015.0
# 11       SK  2023-04-03         976595.0            921830.0
# 12       YT  2023-04-03          37290.0             35964.0
#
#     Booster vaccine: 3  Booster vaccine: 4  Total vaccine  \
# ...

# %%
len(vaccine_df["Vaccine dose:1 "])
# Out:
# 13

# %%
x_axis = np.arange(0, len(vaccine_df["Vaccine dose:1 "]), 1)
plt.yscale('linear')

plt.ticklabel_format(style='plain')
plt.bar((x_axis - 0.4), vaccine_df["Vaccine dose:1 "], 0.2, color='red')
plt.bar((x_axis - 0.2), vaccine_df["Booster vaccine: 2"], 0.2, color='blue')
plt.bar(x_axis, vaccine_df["Booster vaccine: 3"], 0.2, color='green')
plt.bar((x_axis + 0.2), vaccine_df["Booster vaccine: 4"], 0.2, color='orange')
plt.xlabel("Provinces")
plt.ylabel("Canadians Vaccinated")
plt.legend(["1", "2", "3", "4"], title = "# of Vaccines")
plt.title("Total Vaccinations per Province")
plt.xticks(x_axis, ['AB', 'BC', 'MB', 'NB', 'NL', 'NS', 'NT', 'NU', 'ON', 'PE', 'QC', 'SK', 'YT'], fontsize=9)
plt.savefig("Output/VaccineTotals.png")
plt.show()

# %%
plt.yscale('linear')
fig, ax = plt.subplots()
plt.ticklabel_format(style='plain')
plt.bar((x_axis - 0.4), vaccine_df["Vaccine coverage dose:1"], 0.2, color='red')
plt.bar((x_axis - 0.2), vaccine_df["Vaccine coverage booster:2"], 0.2, color='blue')
plt.bar(x_axis, vaccine_df["Vaccine coverage booster:3"], 0.2, color='green')
plt.bar((x_axis + 0.2), vaccine_df["Vaccine coverage booster:4"], 0.2, color='orange')
plt.xlabel("Provinces")
plt.ylabel("Percent of Canadians Vaccinated")
plt.legend(["1", "2", "3", "4"], title = "# of Vaccines")
plt.title("Vaccinate Percentages of Provinces")
ax.subplots().yaxis.set_major_formatter('{x:1.0f}%')
plt.xticks(x_axis, ['AB', 'BC', 'MB', 'NB', 'NL', 'NS', 'NT', 'NU', 'ON', 'PE', 'QC', 'SK', 'YT'], fontsize=9)
plt.savefig("Output/VaccinePercentage.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14536\3034916701.py in <module>
#      10 plt.legend(["1", "2", "3", "4"], title = "# of Vaccines")
#      11 plt.title("Vaccinate Percentages of Provinces")
# ---> 12 ax.subplots().yaxis.set_major_formatter('{x:1.0f}%')
#      13 plt.xticks(x_axis, ['AB', 'BC', 'MB', 'NB', 'NL', 'NS', 'NT', 'NU', 'ON', 'PE', 'QC', 'SK', 'YT'], fontsize=9)
#      14 plt.savefig("Output/VaccinePercentage.png")
#
# AttributeError: 'AxesSubplot' object has no attribute 'subplots'
